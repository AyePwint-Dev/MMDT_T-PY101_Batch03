# %% [markdown]
# <a href="https://colab.research.google.com/github/AyePwint-Dev/MMDT_T-PY101_Batch03/blob/main/Ex01_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section introduces the Python Programming uisng Colab. Follow the instructions and complete the exercises.

# %% [markdown]
# # Ex 1 : Check Version

# %% [markdown]
# Using the below cell, Import the required library and check the version of the python in your environment.

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# # Ex2 : Convert Currency.

# %% [markdown]
# Write a program that asks the user for the amount in usd and converts it to British pounds. The exchange rate is from usd to BP is given as 0.82

# %%
usd_amount = input ("Enter the amount in USD: ")
bp_amount = int(usd_amount) *0.82
print("{} usd is equivalent to {} british pound".format(usd_amount, bp_amount))
# Out:
# Enter the amount in USD: 10
# 10 usd is equivalent to 8.2 british pound

# %% [markdown]
# # Ex 3: Temperature Converter

# %% [markdown]
# Write a program that convert temperature in Feranhite to celsius.

# %%
fah = float(input("Enter Fahrenheit temperature: "))

celsius = (fah - 32) * 5 / 9

print("Celsius Temperature:", celsius)
# Out:
# Enter Fahrenheit temperature: 35
# Celsius Temperature: 1.6666666666666667

# %% [markdown]
# # Ex 4: Daily Maths

# %% [markdown]
# You are working in a retail shop. Write a program that computes the total cost for a customer that bought 3 differnt types of fruits : apple, orange, mango. Ask the user to enter the quantity and price for each type.

# %%
apple_qty = int(input("Enter quantity of apples: "))
apple_price = float(input("Enter price per apple: "))

orange_qty = int(input("Enter quantity of oranges: "))
orange_price = float(input("Enter price per orange: "))

mango_qty = int(input("Enter quantity of mangoes: "))
mango_price = float(input("Enter price per mango: "))

total_cost = (
    apple_qty * apple_price +
    orange_qty * orange_price +
    mango_qty * mango_price
)

print("Total cost for the fruits is:", total_cost)
# Out:
# Enter quantity of apples: 5
# Enter price per apple: 1.5
# Enter quantity of oranges: 5
# Enter price per orange: 3
# Enter quantity of mangoes: 10
# Enter price per mango: 2.5
# Total cost for the fruits is: 47.5

# %% [markdown]
# # Ex 5 : Greeting

# %% [markdown]
# Write a program to greet the customer who provides the user name. Your program should ask the name of the customer and print "Hello + customer name"

# %%
user_name = input("Enter your name:")
print("Hello " + user_name)
# Out:
# Enter your name:Aye Pwint
# Hello Aye Pwint

# %% [markdown]
# # Ex 6: Random Number
# Write a program that generates a random number, x, between 1 and 50, a random number y between 2 and 5, and computes x^y.

# %%
from random import randint
x = randint(1,50)
print('A random number x between 1 and 50: ', x)
y = randint(2,5)
print('A random number y between 2 and 5: ', y)
result = x**y
print("The computation result of x^y is: ",result)
# Out:
# A random number x between 1 and 50:  3
# A random number y between 2 and 5:  4
# The computation result of x^y is:  81

# %% [markdown]
# # Ex 7: Greet many times.
# Write a program that generates a random number between 1 and 10 and prints your name that many times.

# %%
from random import randint
hello = "Aye Pwint "
time = randint(1,10)
print(time * hello)
# Out:
# Aye Pwint Aye Pwint Aye Pwint Aye Pwint Aye Pwint Aye Pwint

# %% [markdown]
# # Ex 8: Computing.
# Write a program that asks the user to enter two numbers, x and y, and computes |x-y|/(x+y).

# %%
x = int(input("Enter number for x:"))
y = int(input("Enter number for y:"))
result = abs(x-y) / (x+y)
print("Result =", result)
# Out:
# Enter number for x:3
# Enter number for y:1
# Result = 0.5

# %% [markdown]
# # Ex 9: Computing
#
# Write a program that asks the user for a number of seconds and prints out how many minutes and seconds that is. For instance, 200 seconds is 3 minutes and 20 seconds.

# %%
seconds = int(input("Enter number of seconds: "))

minutes = seconds // 60
remaining_seconds = seconds % 60

print(minutes, "minutes and", remaining_seconds, "seconds")
# Out:
# Enter number of seconds: 26543
# 442 minutes and 23 seconds

# %% [markdown]
# # Ex 10: Using Math Module
#
# Write a program that asks the user for a number and then prints out the sine, cosine, and tangent of that number.

# %%
import math

num = float(input("Enter a number:"))
sine_value = math.sin(num)
cos_value = math.cos(num)
tan_value = math.tan(num)
print(sine_value)
print(cos_value)
print(tan_value)
# Out:
# Enter a number:35
# -0.428182669496151
# -0.9036922050915067
# 0.473814720414451
